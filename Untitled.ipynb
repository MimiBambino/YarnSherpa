# %%
import json
with open("yarnsherpa-yarns-export.json") as json_file:
    data = json.load(json_file)   
len(data)
# Out:
# 1436

# %%
import shutil
import time
import requests

for i in range(len(data)):
    time.sleep(3)
    url = data[i]["image"]
    new_file = data[i]["image"][-9:]
    print new_file + " is being downloaded"
    response = requests.get(url, stream=True)
    with open(new_file, 'wb') as out_file:
        shutil.copyfileobj(response.raw, out_file)
    del response
# Out:
# 26470.jpg is being downloaded
# 26548.jpg is being downloaded
# 26549.jpg is being downloaded
# 26555.jpg is being downloaded
# 26608.jpg is being downloaded
# 26467.jpg is being downloaded
# 26468.jpg is being downloaded
# 26469.jpg is being downloaded
# 26471.jpg is being downloaded
# 26472.jpg is being downloaded
# 26473.jpg is being downloaded
# 26474.jpg is being downloaded
# 26550.jpg is being downloaded
# 26551.jpg is being downloaded
# 26552.jpg is being downloaded
# 26553.jpg is being downloaded
# 26554.jpg is being downloaded
# 25884.jpg is being downloaded
# 25885.jpg is being downloaded
# 25266.jpg is being downloaded
# 23419.jpg is being downloaded
# 23420.jpg is being downloaded
# 23421.jpg is being downloaded
# 23422.jpg is being downloaded
# 23424.jpg is being downloaded
# 23425.jpg is being downloaded
# 23427.jpg is being downloaded
# 23430.jpg is being downloaded
# 23432.jpg is being downloaded
# 23433.jpg is being downloaded
# 23438.jpg is being downloaded
# 23439.jpg is being downloaded
# 23442.jpg is being downloaded
# 23764.jpg is being downloaded
# 23766.jpg is being downloaded
# 23774.jpg is being downloaded
# 23893.jpg is being downloaded
# 23894.jpg is being downloaded
# 23896.jpg is being downloaded
# 23897.jpg is being downloaded
# 23898.jpg is being downloaded
# 23899.jpg is being downloaded
# 23900.jpg is being downloaded
# 24065.jpg is being downloaded
# 24066.jpg is being downloaded
# 24071.jpg is being downloaded
# 24074.jpg is being downloaded
# 24075.jpg is being downloaded
# 24076.jpg is being downloaded
# 24077.jpg is being downloaded
# 24272.jpg is being downloaded
# 24273.jpg is being downloaded
# 24274.jpg is being downloaded
# 24275.jpg is being downloaded
# 24277.jpg is being downloaded
# 24279.jpg is being downloaded
# 24280.jpg is being downloaded
# 24283.jpg is being downloaded
# 24647.jpg is being downloaded
# 24648.jpg is being downloaded
# 24649.jpg is being downloaded
# 24650.jpg is being downloaded
# 24652.jpg is being downloaded
# 24653.jpg is being downloaded
# 24655.jpg is being downloaded
# 25064.jpg is being downloaded
# 25065.jpg is being downloaded
# 25066.jpg is being downloaded
# 25067.jpg is being downloaded
# 25068.jpg is being downloaded
# 25069.jpg is being downloaded
# 25070.jpg is being downloaded
# 25071.jpg is being downloaded
# 25072.jpg is being downloaded
# 25073.jpg is being downloaded
# 25074.jpg is being downloaded
# 25075.jpg is being downloaded
# 25632.jpg is being downloaded
# 25633.jpg is being downloaded
# 25634.jpg is being downloaded
# 25635.jpg is being downloaded
# 25636.jpg is being downloaded
# 25637.jpg is being downloaded
# 25638.jpg is being downloaded
# 25639.jpg is being downloaded
# 25640.jpg is being downloaded
# 25641.jpg is being downloaded
# 25642.jpg is being downloaded
# 25643.jpg is being downloaded
# 25644.jpg is being downloaded
# 25645.jpg is being downloaded
# 25646.jpg is being downloaded
# 25647.jpg is being downloaded
# 25648.jpg is being downloaded
# 25649.jpg is being downloaded
# 25651.jpg is being downloaded
# 25652.jpg is being downloaded
# 25753.jpg is being downloaded
# 25971.jpg is being downloaded
# 25973.jpg is being downloaded
# 25974.jpg is being downloaded
# 25975.jpg is being downloaded
# 25976.jpg is being downloaded
# 25977.jpg is being downloaded
# 25978.jpg is being downloaded
# 25979.jpg is being downloaded
# 25980.jpg is being downloaded
# 25981.jpg is being downloaded
# 25982.jpg is being downloaded
# 25983.jpg is being downloaded
# 25984.jpg is being downloaded
# 25985.jpg is being downloaded
# 25986.jpg is being downloaded
# 25988.jpg is being downloaded
# 25989.jpg is being downloaded
# 25990.jpg is being downloaded
# 25991.jpg is being downloaded
# 25992.jpg is being downloaded
# 26158.jpg is being downloaded
# 26159.jpg is being downloaded
# 23496.jpg is being downloaded
# 23502.jpg is being downloaded
# 23505.jpg is being downloaded
# 23506.jpg is being downloaded
# 24169.jpg is being downloaded
# 24418.jpg is being downloaded
# 24807.jpg is being downloaded
# 25370.jpg is being downloaded
# 25371.jpg is being downloaded
# 25372.jpg is being downloaded
# 25915.jpg is being downloaded
# 25916.jpg is being downloaded
# 26756.jpg is being downloaded
# 26757.jpg is being downloaded
# 26758.jpg is being downloaded
# 26759.jpg is being downloaded
# 26760.jpg is being downloaded
# 26761.jpg is being downloaded
# 26762.jpg is being downloaded
# 26763.jpg is being downloaded
# 26764.jpg is being downloaded
# 26765.jpg is being downloaded
# 26766.jpg is being downloaded
# 26767.jpg is being downloaded
# 26768.jpg is being downloaded
# 26769.jpg is being downloaded
# 26770.jpg is being downloaded
# 26771.jpg is being downloaded
# 26772.jpg is being downloaded
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-14-588d7bb8b4e4> in <module>()
#       8     new_file = data[i]["image"][-9:]
#       9     print new_file + " is being downloaded"
# ---> 10     response = requests.get(url, stream=True)
#      11     with open(new_file, 'wb') as out_file:
#      12         shutil.copyfileobj(response.raw, out_file)
#
# /home/cynthia/anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, **kwargs)
#      53
#      54     kwargs.setdefault('allow_redirects', True)
# ---> 55     return request('get', url, **kwargs)
#      56
#      57
#
# /home/cynthia/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ---> 44     return session.request(method=method, url=url, **kwargs)
#      45
#      46
#
# /home/cynthia/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert)
#     333             'allow_redirects': allow_redirects,
#     334         }
# --> 335         resp = self.send(prep, **send_kwargs)
#     336
#     337         return resp
#
# /home/cynthia/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     436         start = datetime.utcnow()
#     437         # Send the request
# --> 438         r = adapter.send(request, **kwargs)
#     439         # Total elapsed time of the request (approximately)
#     440         r.elapsed = datetime.utcnow() - start
#
# /home/cynthia/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     325
#     326         except MaxRetryError as e:
# --> 327             raise ConnectionError(e)
#     328
#     329         except (_SSLError, _HTTPError) as e:
#
# ConnectionError: HTTPConnectionPool(host='d2q9kw5vp0we94.cloudfront.net', port=80): Max retries exceeded with url: /Yarn_Color_Detail/26772.jpg (Caused by <class 'socket.gaierror'>: [Errno -3] Temporary failure in name resolution)

# %%
for i in range(len(data)):
    url = data[i]["image"][-9:]
# Out:
# BigY32.ico  favicon.ico  favicon.png  yarn.jpg  yarn_small.jpg

# %%
for i in range(len(data)):
    if data[i]["image"] == "http://d2q9kw5vp0we94.cloudfront.net/Yarn_Color_Detail/26772.jpg":
        print i
# Out:
# 148

# %%
new_data = data[149:]
len(new_data)
# Out:
# 1287

# %%
for i in range(len(new_data)):
    time.sleep(10)
    url = new_data[i]["image"]
    new_file = new_data[i]["image"][-9:]
    print new_file + " is being downloaded"
    response = requests.get(url, stream=True)
    with open(new_file, 'wb') as out_file:
        shutil.copyfileobj(response.raw, out_file)
    del response
# Out:
# 26773.jpg is being downloaded
# 26774.jpg is being downloaded
# 26775.jpg is being downloaded
# 26776.jpg is being downloaded
# 26777.jpg is being downloaded
# 26778.jpg is being downloaded
# 26779.jpg is being downloaded
# 26780.jpg is being downloaded
# 26781.jpg is being downloaded
# 26782.jpg is being downloaded
# 26783.jpg is being downloaded
# 26784.jpg is being downloaded
# 26785.jpg is being downloaded
# 26786.jpg is being downloaded
# 26787.jpg is being downloaded
# 26788.jpg is being downloaded
# 26789.jpg is being downloaded
# 26790.jpg is being downloaded
# 26791.jpg is being downloaded
# 26792.jpg is being downloaded
# 26793.jpg is being downloaded
# 26794.jpg is being downloaded
# 26795.jpg is being downloaded
# 26796.jpg is being downloaded
# 26797.jpg is being downloaded
# 26798.jpg is being downloaded
# 26799.jpg is being downloaded
# 26800.jpg is being downloaded
# 26801.jpg is being downloaded
# 26802.jpg is being downloaded
# 26803.jpg is being downloaded
# 26804.jpg is being downloaded
# 26805.jpg is being downloaded
# 26806.jpg is being downloaded
# 26607.jpg is being downloaded
# 26475.jpg is being downloaded
# 26476.jpg is being downloaded
# 26477.jpg is being downloaded
# 26478.jpg is being downloaded
# 26479.jpg is being downloaded
# 26480.jpg is being downloaded
# 26481.jpg is being downloaded
# 26482.jpg is being downloaded
# 26542.jpg is being downloaded
# 26543.jpg is being downloaded
# 26544.jpg is being downloaded
# 25867.jpg is being downloaded
# 25868.jpg is being downloaded
# 25248.jpg is being downloaded
# 26540.jpg is being downloaded
# 26541.jpg is being downloaded
# 26545.jpg is being downloaded
# 26546.jpg is being downloaded
# 26547.jpg is being downloaded
# 26741.jpg is being downloaded
# 26742.jpg is being downloaded
# 26743.jpg is being downloaded
# 26744.jpg is being downloaded
# 26745.jpg is being downloaded
# 23718.jpg is being downloaded
# 23721.jpg is being downloaded
# 23722.jpg is being downloaded
# 23723.jpg is being downloaded
# 23724.jpg is being downloaded
# 23728.jpg is being downloaded
# 23729.jpg is being downloaded
# 23730.jpg is being downloaded
# 23731.jpg is being downloaded
# 23733.jpg is being downloaded
# 23737.jpg is being downloaded
# 23999.jpg is being downloaded
# 24000.jpg is being downloaded
# 24001.jpg is being downloaded
# 24002.jpg is being downloaded
# 24003.jpg is being downloaded
# 24004.jpg is being downloaded
# 24005.jpg is being downloaded
# 24006.jpg is being downloaded
# 24007.jpg is being downloaded
# 24008.jpg is being downloaded
# 24009.jpg is being downloaded
# 24010.jpg is being downloaded
# 24011.jpg is being downloaded
# 24012.jpg is being downloaded
# 24013.jpg is being downloaded
# 24014.jpg is being downloaded
# 24015.jpg is being downloaded
# 24239.jpg is being downloaded
# 24240.jpg is being downloaded
# 24241.jpg is being downloaded
# 24242.jpg is being downloaded
# 24243.jpg is being downloaded
# 24244.jpg is being downloaded
# 24245.jpg is being downloaded
# 24246.jpg is being downloaded
# 24247.jpg is being downloaded
# 24248.jpg is being downloaded
# 24249.jpg is being downloaded
# 24250.jpg is being downloaded
# 24251.jpg is being downloaded
# 24252.jpg is being downloaded
# 24253.jpg is being downloaded
# 24254.jpg is being downloaded
# 24255.jpg is being downloaded
# 24256.jpg is being downloaded
# 24257.jpg is being downloaded
# 24258.jpg is being downloaded
# 24259.jpg is being downloaded
# 24553.jpg is being downloaded
# 24554.jpg is being downloaded
# 24555.jpg is being downloaded
# 24556.jpg is being downloaded
# 24557.jpg is being downloaded
# 24558.jpg is being downloaded
# 24559.jpg is being downloaded
# 24560.jpg is being downloaded
# 24561.jpg is being downloaded
# 24562.jpg is being downloaded
# 24563.jpg is being downloaded
# 24564.jpg is being downloaded
# 24565.jpg is being downloaded
# 24566.jpg is being downloaded
# 24567.jpg is being downloaded
# 24568.jpg is being downloaded
# 24569.jpg is being downloaded
# 24570.jpg is being downloaded
# 24571.jpg is being downloaded
# 24572.jpg is being downloaded
# 24573.jpg is being downloaded
# 24574.jpg is being downloaded
# 24575.jpg is being downloaded
# 24576.jpg is being downloaded
# 24577.jpg is being downloaded
# 24578.jpg is being downloaded
# 24579.jpg is being downloaded
# 24580.jpg is being downloaded
# 24581.jpg is being downloaded
# 24582.jpg is being downloaded
# 24583.jpg is being downloaded
# 24584.jpg is being downloaded
# 24585.jpg is being downloaded
# 24586.jpg is being downloaded
# 25084.jpg is being downloaded
# 25085.jpg is being downloaded
# 25086.jpg is being downloaded
# 25088.jpg is being downloaded
# 25089.jpg is being downloaded
# 25090.jpg is being downloaded
# 25091.jpg is being downloaded
# 25092.jpg is being downloaded
# 25093.jpg is being downloaded
# 25094.jpg is being downloaded
# 25095.jpg is being downloaded
# 25096.jpg is being downloaded
# 25097.jpg is being downloaded
# 25098.jpg is being downloaded
# 25099.jpg is being downloaded
# 25100.jpg is being downloaded
# 25530.jpg is being downloaded
# 25531.jpg is being downloaded
# 25532.jpg is being downloaded
# 25533.jpg is being downloaded
# 25534.jpg is being downloaded
# 25535.jpg is being downloaded
# 25536.jpg is being downloaded
# 25537.jpg is being downloaded
# 25538.jpg is being downloaded
# 25539.jpg is being downloaded
# 25540.jpg is being downloaded
# 25541.jpg is being downloaded

# %%
from firebase import Firebase

for i in range(len(data))
    url = 'https://yarnsherpa.firebaseio.com/yarns' + str(i)
    f = Firebase(url)
    new_image = data[i]["image"][-9:]
    r = f.update({ "image": new_image })

# %%
import PIL
from PIL import Image

basewidth = 300
img = Image.open("fullsized_image.jpg")
wpercent = (basewidth / float(img.size[0]))
hsize = int((float(img.size[1]) * float(wpercent)))
img = img.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
img.save("resized_image.jpg")
